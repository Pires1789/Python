# %% [markdown]
# <a href="https://colab.research.google.com/github/Pires1789/Python/blob/main/Dicionario_Pndas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# ## Comandos básicos do Pandas

# %%
#Criando um dataframe

data = {'Nome': ['Alice', 'Bob', 'Charlie'],
        'Idade': [25, 30, 35],
        'Cidade': ['Nova York', 'Los Angeles', 'Chicago']}
df = pd.DataFrame(data)

# %%
#Primeiras cinco colunas do dataframe.

df.head()
# Out:
#       Nome  Idade       Cidade
# 0    Alice     25    Nova York
# 1      Bob     30  Los Angeles
# 2  Charlie     35      Chicago

# %%
#Função para apresentar uma lista com o título das colunas.
df.columns

# %%
#Forma de apresentar apenas uma coluna de um DataFrame

df[['city']]

# %%
#Selecionando mais de uma coluna

df[['city', 'relevent_experience']]

# %%
#Selecionando colunas com base em condições

jovens = df[df['Idade'] < 30]
# Out:
#     Nome  Idade     Cidade
# 0  Alice     25  Nova York

# %%
#Adicionar colunas

df['Salário'] = [50000, 60000, 75000]
df
# Out:
#       Nome  Idade       Cidade  Salário
# 0    Alice     25    Nova York    50000
# 1      Bob     30  Los Angeles    60000
# 2  Charlie     35      Chicago    75000

# %%
#Realizando agregações

media_idade = df['Idade'].mean()
soma_salarios = df['Salário'].sum()

media_idade
# Out:
# 30.0

# %%
#Criando um cálculo e incluindo no data frame
media_idade = df['Idade'].mean()

df['Média'] = media_idade

df
# Out:
#       Nome  Idade       Cidade  Média
# 0    Alice     25    Nova York   30.0
# 1      Bob     30  Los Angeles   30.0
# 2  Charlie     35      Chicago   30.0

# %%
# Retornar os valores em lista

df.values
# Out:
# array([['Alice', 25, 'Nova York'],
#        ['Bob', 30, 'Los Angeles'],
#        ['Charlie', 35, 'Chicago']], dtype=object)

# %%
# Verificar o tipo dos objetos do dataframe

df.dtypes
# Out:
# Nome      object
# Idade      int64
# Cidade    object
# dtype: object

# %%
# Filtrando pelo indice. A lista indicada em items pode conter apenas um indice
# Mas também pode conter mais de um indice, conforme o exemplo abaixo.

df.filter(items = [1,2], axis= 0)
# Out:
#       Nome  Idade       Cidade
# 1      Bob     30  Los Angeles
# 2  Charlie     35      Chicago
